# %% [markdown]
# <a href="https://colab.research.google.com/github/ronknight/brevo-pyplot/blob/main/Brevo_Batch_Email_Metrics_Percentage.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Data
categories = ['Delivered', 'Estimated Openers', 'Trackable Openers',
              'Unique Clickers', 'Hard Bounced', 'Soft Bounced', 'Bounced',
              'Complaint', 'Blocked', 'Unsubscribe', 'Double Opt-In']

batch_data = {
    'Brevo': ['Batch1-A_B-599999-539901-03-21', 'Batch1-C-541103-03/22', 'Batch1-D-541105-03/22-3PM', 'Batch1-E-LQR-03-25', 'Batch1-H-PHARMACY-0326'],
    'Delivered': [88, 85, 82, 83, 92],
    'Estimated Openers': [13, 16, 8, 4, 13],
    'Trackable Openers': [11, 11, 6, 4, 12],
    'Unique Clickers': [8, 9, 6, 3, 13],
    'Hard Bounced': [13, 14, 20, 17, 0],
    'Soft Bounced': [2, 4, 1, 2, 3],
    'Bounced': [14, 18, 21, 19, 6],
    'Complaint': [0, 0, 0, 0, 0],
    'Blocked': [0, 0, 0, 0, 0],
    'Unsubscribe': [2, 2, 0, 1, 0],
    'Double Opt-In': [5, 8, 4, 1, 5]
}

# Creating DataFrame
df = pd.DataFrame(batch_data)
df.set_index('Brevo', inplace=True)

# Plotting
ax = df.plot(kind='bar', stacked=True, figsize=(10, 6))
plt.title('Email Metrics by Batch')
plt.xlabel('Batch')
plt.ylabel('Percentage')
plt.xticks(rotation=45)
plt.legend(title='Metrics', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()
